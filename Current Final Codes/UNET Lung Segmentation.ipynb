# %% [markdown]
# # Lung segmentation from Chest X-Ray dataset
#
#
#
#
# ## Take a look at the dataset

# %%
import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.path.join(r"C:\Users\vinee\OneDrive\Desktop\UNET_DATA\archive\data\Lung Segmentation\CXR_png")
mask_path = os.path.join(r"C:\Users\vinee\OneDrive\Desktop\UNET_DATA\archive\data\Lung Segmentation\masks")

# %%
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in tqdm(testing_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in tqdm(training_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
def plotMask(X,y):
    sample = []
    
    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
# Load training and testing data
dim = 128*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [01:11<00:00,  7.87it/s]
# 100%|██████████| 138/138 [00:40<00:00,  3.42it/s]

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
X_train.shape
# Out:
# (566, 256, 256, 1)

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)

    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2),padding = "same")(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2),padding="same")(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2),padding = "same")(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2), padding="same")(conv4)


    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)


    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# #### Compile and train the Unet Model

# %%
model = unet(input_size=(256,256,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# c:\Users\vinee\miniconda3\envs\tf2.4\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ## Callbacks, Early Stopping and Reduced LR

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15)
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
from IPython.display import clear_output
from keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4), 
              loss=[dice_coef_loss], 
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0, 
                                                            (mask>127).astype(np.float32), 
                                                             test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                        batch_size = 16,
                       epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# c:\Users\vinee\miniconda3\envs\tf2.4\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 36/36 [==============================] - ETA: 0s - loss: -0.3988 - dice_coef: 0.4013 - binary_accuracy: 0.6517
# Epoch 1: val_loss improved from inf to -0.54530, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 31s 449ms/step - loss: -0.3988 - dice_coef: 0.4013 - binary_accuracy: 0.6517 - val_loss: -0.5453 - val_dice_coef: 0.5453 - val_binary_accuracy: 0.6053 - lr: 2.0000e-04
# Epoch 2/50
# 36/36 [==============================] - ETA: 0s - loss: -0.6996 - dice_coef: 0.7016 - binary_accuracy: 0.8009
# Epoch 2: val_loss improved from -0.54530 to -0.87502, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 318ms/step - loss: -0.6996 - dice_coef: 0.7016 - binary_accuracy: 0.8009 - val_loss: -0.8750 - val_dice_coef: 0.8750 - val_binary_accuracy: 0.9380 - lr: 2.0000e-04
# Epoch 3/50
# 36/36 [==============================] - ETA: 0s - loss: -0.8876 - dice_coef: 0.8878 - binary_accuracy: 0.9438
# Epoch 3: val_loss improved from -0.87502 to -0.90096, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 318ms/step - loss: -0.8876 - dice_coef: 0.8878 - binary_accuracy: 0.9438 - val_loss: -0.9010 - val_dice_coef: 0.9010 - val_binary_accuracy: 0.9495 - lr: 2.0000e-04
# Epoch 4/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9215 - dice_coef: 0.9216 - binary_accuracy: 0.9606
# Epoch 4: val_loss improved from -0.90096 to -0.92864, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 317ms/step - loss: -0.9215 - dice_coef: 0.9216 - binary_accuracy: 0.9606 - val_loss: -0.9286 - val_dice_coef: 0.9286 - val_binary_accuracy: 0.9656 - lr: 2.0000e-04
# Epoch 5/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9270 - dice_coef: 0.9272 - binary_accuracy: 0.9634
# Epoch 5: val_loss did not improve from -0.92864
# 36/36 [==============================] - 11s 315ms/step - loss: -0.9270 - dice_coef: 0.9272 - binary_accuracy: 0.9634 - val_loss: -0.9212 - val_dice_coef: 0.9212 - val_binary_accuracy: 0.9596 - lr: 2.0000e-04
# Epoch 6/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9359 - dice_coef: 0.9358 - binary_accuracy: 0.9677
# Epoch 6: val_loss improved from -0.92864 to -0.93981, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 318ms/step - loss: -0.9359 - dice_coef: 0.9358 - binary_accuracy: 0.9677 - val_loss: -0.9398 - val_dice_coef: 0.9398 - val_binary_accuracy: 0.9703 - lr: 2.0000e-04
# Epoch 7/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9418 - dice_coef: 0.9420 - binary_accuracy: 0.9708
# Epoch 7: val_loss improved from -0.93981 to -0.94464, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 318ms/step - loss: -0.9418 - dice_coef: 0.9420 - binary_accuracy: 0.9708 - val_loss: -0.9446 - val_dice_coef: 0.9446 - val_binary_accuracy: 0.9734 - lr: 2.0000e-04
# Epoch 8/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9428 - dice_coef: 0.9428 - binary_accuracy: 0.9713
# Epoch 8: val_loss did not improve from -0.94464
# 36/36 [==============================] - 11s 317ms/step - loss: -0.9428 - dice_coef: 0.9428 - binary_accuracy: 0.9713 - val_loss: -0.9407 - val_dice_coef: 0.9407 - val_binary_accuracy: 0.9702 - lr: 2.0000e-04
# Epoch 9/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9444 - dice_coef: 0.9445 - binary_accuracy: 0.9720
# Epoch 9: val_loss improved from -0.94464 to -0.94995, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 11s 319ms/step - loss: -0.9444 - dice_coef: 0.9445 - binary_accuracy: 0.9720 - val_loss: -0.9500 - val_dice_coef: 0.9500 - val_binary_accuracy: 0.9755 - lr: 2.0000e-04
# Epoch 10/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9480 - dice_coef: 0.9481 - binary_accuracy: 0.9739
# Epoch 10: val_loss did not improve from -0.94995
# 36/36 [==============================] - 11s 318ms/step - loss: -0.9480 - dice_coef: 0.9481 - binary_accuracy: 0.9739 - val_loss: -0.9489 - val_dice_coef: 0.9489 - val_binary_accuracy: 0.9753 - lr: 2.0000e-04
# Epoch 11/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9493 - dice_coef: 0.9493 - binary_accuracy: 0.9746
# Epoch 11: val_loss improved from -0.94995 to -0.95335, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 320ms/step - loss: -0.9493 - dice_coef: 0.9493 - binary_accuracy: 0.9746 - val_loss: -0.9533 - val_dice_coef: 0.9533 - val_binary_accuracy: 0.9772 - lr: 2.0000e-04
# Epoch 12/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9518 - dice_coef: 0.9517 - binary_accuracy: 0.9758
# Epoch 12: val_loss improved from -0.95335 to -0.95498, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 321ms/step - loss: -0.9518 - dice_coef: 0.9517 - binary_accuracy: 0.9758 - val_loss: -0.9550 - val_dice_coef: 0.9550 - val_binary_accuracy: 0.9778 - lr: 2.0000e-04
# Epoch 13/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9525 - dice_coef: 0.9525 - binary_accuracy: 0.9762
# Epoch 13: val_loss improved from -0.95498 to -0.95527, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 322ms/step - loss: -0.9525 - dice_coef: 0.9525 - binary_accuracy: 0.9762 - val_loss: -0.9553 - val_dice_coef: 0.9553 - val_binary_accuracy: 0.9780 - lr: 2.0000e-04
# Epoch 14/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9540 - dice_coef: 0.9538 - binary_accuracy: 0.9768
# Epoch 14: val_loss did not improve from -0.95527
# 36/36 [==============================] - 11s 319ms/step - loss: -0.9540 - dice_coef: 0.9538 - binary_accuracy: 0.9768 - val_loss: -0.9532 - val_dice_coef: 0.9532 - val_binary_accuracy: 0.9769 - lr: 2.0000e-04
# Epoch 15/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9553 - dice_coef: 0.9553 - binary_accuracy: 0.9775
# Epoch 15: val_loss improved from -0.95527 to -0.95822, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 323ms/step - loss: -0.9553 - dice_coef: 0.9553 - binary_accuracy: 0.9775 - val_loss: -0.9582 - val_dice_coef: 0.9582 - val_binary_accuracy: 0.9795 - lr: 2.0000e-04
# Epoch 16/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9570 - dice_coef: 0.9569 - binary_accuracy: 0.9785
# Epoch 16: val_loss did not improve from -0.95822
# 36/36 [==============================] - 12s 320ms/step - loss: -0.9570 - dice_coef: 0.9569 - binary_accuracy: 0.9785 - val_loss: -0.9573 - val_dice_coef: 0.9573 - val_binary_accuracy: 0.9788 - lr: 2.0000e-04
# Epoch 17/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9580 - dice_coef: 0.9580 - binary_accuracy: 0.9790
# Epoch 17: val_loss improved from -0.95822 to -0.95937, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 323ms/step - loss: -0.9580 - dice_coef: 0.9580 - binary_accuracy: 0.9790 - val_loss: -0.9594 - val_dice_coef: 0.9594 - val_binary_accuracy: 0.9801 - lr: 2.0000e-04
# Epoch 18/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9587 - dice_coef: 0.9588 - binary_accuracy: 0.9793
# Epoch 18: val_loss did not improve from -0.95937
# 36/36 [==============================] - 12s 321ms/step - loss: -0.9587 - dice_coef: 0.9588 - binary_accuracy: 0.9793 - val_loss: -0.9575 - val_dice_coef: 0.9575 - val_binary_accuracy: 0.9793 - lr: 2.0000e-04
# Epoch 19/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9593 - dice_coef: 0.9592 - binary_accuracy: 0.9795
# Epoch 19: val_loss improved from -0.95937 to -0.96125, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 323ms/step - loss: -0.9593 - dice_coef: 0.9592 - binary_accuracy: 0.9795 - val_loss: -0.9612 - val_dice_coef: 0.9612 - val_binary_accuracy: 0.9810 - lr: 2.0000e-04
# Epoch 20/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9601 - dice_coef: 0.9600 - binary_accuracy: 0.9799
# Epoch 20: val_loss did not improve from -0.96125
# 36/36 [==============================] - 12s 321ms/step - loss: -0.9601 - dice_coef: 0.9600 - binary_accuracy: 0.9799 - val_loss: -0.9610 - val_dice_coef: 0.9610 - val_binary_accuracy: 0.9807 - lr: 2.0000e-04
# Epoch 21/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9581 - dice_coef: 0.9582 - binary_accuracy: 0.9790
# Epoch 21: val_loss did not improve from -0.96125
# 36/36 [==============================] - 12s 321ms/step - loss: -0.9581 - dice_coef: 0.9582 - binary_accuracy: 0.9790 - val_loss: -0.9576 - val_dice_coef: 0.9576 - val_binary_accuracy: 0.9790 - lr: 2.0000e-04
# Epoch 22/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9590 - dice_coef: 0.9592 - binary_accuracy: 0.9794
# Epoch 22: val_loss improved from -0.96125 to -0.96147, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 324ms/step - loss: -0.9590 - dice_coef: 0.9592 - binary_accuracy: 0.9794 - val_loss: -0.9615 - val_dice_coef: 0.9615 - val_binary_accuracy: 0.9812 - lr: 2.0000e-04
# Epoch 23/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9606 - dice_coef: 0.9607 - binary_accuracy: 0.9803
# Epoch 23: val_loss improved from -0.96147 to -0.96248, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 328ms/step - loss: -0.9606 - dice_coef: 0.9607 - binary_accuracy: 0.9803 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9816 - lr: 2.0000e-04
# Epoch 24/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9618 - dice_coef: 0.9618 - binary_accuracy: 0.9808
# Epoch 24: val_loss improved from -0.96248 to -0.96264, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 325ms/step - loss: -0.9618 - dice_coef: 0.9618 - binary_accuracy: 0.9808 - val_loss: -0.9626 - val_dice_coef: 0.9626 - val_binary_accuracy: 0.9817 - lr: 2.0000e-04
# Epoch 25/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9626 - dice_coef: 0.9627 - binary_accuracy: 0.9812
# Epoch 25: val_loss improved from -0.96264 to -0.96312, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 325ms/step - loss: -0.9626 - dice_coef: 0.9627 - binary_accuracy: 0.9812 - val_loss: -0.9631 - val_dice_coef: 0.9631 - val_binary_accuracy: 0.9819 - lr: 2.0000e-04
# Epoch 26/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9629 - dice_coef: 0.9628 - binary_accuracy: 0.9814
# Epoch 26: val_loss did not improve from -0.96312
# 36/36 [==============================] - 12s 325ms/step - loss: -0.9629 - dice_coef: 0.9628 - binary_accuracy: 0.9814 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9814 - lr: 2.0000e-04
# Epoch 27/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9631 - dice_coef: 0.9631 - binary_accuracy: 0.9814
# Epoch 27: val_loss did not improve from -0.96312
# 36/36 [==============================] - 12s 325ms/step - loss: -0.9631 - dice_coef: 0.9631 - binary_accuracy: 0.9814 - val_loss: -0.9630 - val_dice_coef: 0.9630 - val_binary_accuracy: 0.9819 - lr: 2.0000e-04
# Epoch 28/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9629 - dice_coef: 0.9626 - binary_accuracy: 0.9814
# Epoch 28: val_loss did not improve from -0.96312
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 36/36 [==============================] - 12s 328ms/step - loss: -0.9629 - dice_coef: 0.9626 - binary_accuracy: 0.9814 - val_loss: -0.9616 - val_dice_coef: 0.9616 - val_binary_accuracy: 0.9808 - lr: 2.0000e-04
# Epoch 29/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9641 - dice_coef: 0.9641 - binary_accuracy: 0.9820
# Epoch 29: val_loss improved from -0.96312 to -0.96423, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 329ms/step - loss: -0.9641 - dice_coef: 0.9641 - binary_accuracy: 0.9820 - val_loss: -0.9642 - val_dice_coef: 0.9642 - val_binary_accuracy: 0.9824 - lr: 1.0000e-04
# Epoch 30/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9649 - dice_coef: 0.9650 - binary_accuracy: 0.9824
# Epoch 30: val_loss improved from -0.96423 to -0.96485, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 329ms/step - loss: -0.9649 - dice_coef: 0.9650 - binary_accuracy: 0.9824 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9827 - lr: 1.0000e-04
# Epoch 31/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9655 - dice_coef: 0.9656 - binary_accuracy: 0.9826
# Epoch 31: val_loss improved from -0.96485 to -0.96525, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 331ms/step - loss: -0.9655 - dice_coef: 0.9656 - binary_accuracy: 0.9826 - val_loss: -0.9652 - val_dice_coef: 0.9652 - val_binary_accuracy: 0.9829 - lr: 1.0000e-04
# Epoch 32/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9827
# Epoch 32: val_loss did not improve from -0.96525
# 36/36 [==============================] - 12s 330ms/step - loss: -0.9657 - dice_coef: 0.9657 - binary_accuracy: 0.9827 - val_loss: -0.9641 - val_dice_coef: 0.9641 - val_binary_accuracy: 0.9822 - lr: 1.0000e-04
# Epoch 33/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9657 - dice_coef: 0.9659 - binary_accuracy: 0.9828
# Epoch 33: val_loss did not improve from -0.96525
# 36/36 [==============================] - 12s 330ms/step - loss: -0.9657 - dice_coef: 0.9659 - binary_accuracy: 0.9828 - val_loss: -0.9650 - val_dice_coef: 0.9650 - val_binary_accuracy: 0.9829 - lr: 1.0000e-04
# Epoch 34/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9661 - dice_coef: 0.9662 - binary_accuracy: 0.9830
# Epoch 34: val_loss improved from -0.96525 to -0.96550, saving model to cxr_reg_weights.best.hdf5
# 36/36 [==============================] - 12s 331ms/step - loss: -0.9661 - dice_coef: 0.9662 - binary_accuracy: 0.9830 - val_loss: -0.9655 - val_dice_coef: 0.9655 - val_binary_accuracy: 0.9831 - lr: 1.0000e-04
# Epoch 35/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9667 - dice_coef: 0.9665 - binary_accuracy: 0.9833
# Epoch 35: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 330ms/step - loss: -0.9667 - dice_coef: 0.9665 - binary_accuracy: 0.9833 - val_loss: -0.9651 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 36/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9663 - dice_coef: 0.9664 - binary_accuracy: 0.9831
# Epoch 36: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 331ms/step - loss: -0.9663 - dice_coef: 0.9664 - binary_accuracy: 0.9831 - val_loss: -0.9644 - val_dice_coef: 0.9644 - val_binary_accuracy: 0.9827 - lr: 1.0000e-04
# Epoch 37/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9666 - dice_coef: 0.9667 - binary_accuracy: 0.9832
# Epoch 37: val_loss did not improve from -0.96550
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 36/36 [==============================] - 12s 333ms/step - loss: -0.9666 - dice_coef: 0.9667 - binary_accuracy: 0.9832 - val_loss: -0.9640 - val_dice_coef: 0.9640 - val_binary_accuracy: 0.9824 - lr: 1.0000e-04
# Epoch 38/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9672 - dice_coef: 0.9672 - binary_accuracy: 0.9835
# Epoch 38: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9672 - dice_coef: 0.9672 - binary_accuracy: 0.9835 - val_loss: -0.9646 - val_dice_coef: 0.9646 - val_binary_accuracy: 0.9826 - lr: 5.0000e-05
# Epoch 39/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9678 - dice_coef: 0.9678 - binary_accuracy: 0.9838
# Epoch 39: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 335ms/step - loss: -0.9678 - dice_coef: 0.9678 - binary_accuracy: 0.9838 - val_loss: -0.9647 - val_dice_coef: 0.9647 - val_binary_accuracy: 0.9826 - lr: 5.0000e-05
# Epoch 40/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9685 - dice_coef: 0.9685 - binary_accuracy: 0.9841
# Epoch 40: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 335ms/step - loss: -0.9685 - dice_coef: 0.9685 - binary_accuracy: 0.9841 - val_loss: -0.9651 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9828 - lr: 5.0000e-05
# Epoch 41/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9687 - dice_coef: 0.9688 - binary_accuracy: 0.9843
# Epoch 41: val_loss did not improve from -0.96550
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9687 - dice_coef: 0.9688 - binary_accuracy: 0.9843 - val_loss: -0.9655 - val_dice_coef: 0.9655 - val_binary_accuracy: 0.9830 - lr: 5.0000e-05
# Epoch 42/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9695 - dice_coef: 0.9693 - binary_accuracy: 0.9846
# Epoch 42: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9695 - dice_coef: 0.9693 - binary_accuracy: 0.9846 - val_loss: -0.9654 - val_dice_coef: 0.9654 - val_binary_accuracy: 0.9829 - lr: 2.5000e-05
# Epoch 43/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9697 - dice_coef: 0.9696 - binary_accuracy: 0.9848
# Epoch 43: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9697 - dice_coef: 0.9696 - binary_accuracy: 0.9848 - val_loss: -0.9651 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9828 - lr: 2.5000e-05
# Epoch 44/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9698 - dice_coef: 0.9697 - binary_accuracy: 0.9848
# Epoch 44: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9698 - dice_coef: 0.9697 - binary_accuracy: 0.9848 - val_loss: -0.9654 - val_dice_coef: 0.9654 - val_binary_accuracy: 0.9830 - lr: 2.5000e-05
# Epoch 45/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9699 - dice_coef: 0.9700 - binary_accuracy: 0.9849
# Epoch 45: val_loss did not improve from -0.96550
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9699 - dice_coef: 0.9700 - binary_accuracy: 0.9849 - val_loss: -0.9650 - val_dice_coef: 0.9650 - val_binary_accuracy: 0.9827 - lr: 2.5000e-05
# Epoch 46/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9701 - dice_coef: 0.9702 - binary_accuracy: 0.9850
# Epoch 46: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9701 - dice_coef: 0.9702 - binary_accuracy: 0.9850 - val_loss: -0.9650 - val_dice_coef: 0.9650 - val_binary_accuracy: 0.9827 - lr: 1.2500e-05
# Epoch 47/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9704 - dice_coef: 0.9705 - binary_accuracy: 0.9851
# Epoch 47: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 336ms/step - loss: -0.9704 - dice_coef: 0.9705 - binary_accuracy: 0.9851 - val_loss: -0.9651 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9828 - lr: 1.2500e-05
# Epoch 48/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9706 - dice_coef: 0.9706 - binary_accuracy: 0.9852
# Epoch 48: val_loss did not improve from -0.96550
# 36/36 [==============================] - 12s 335ms/step - loss: -0.9706 - dice_coef: 0.9706 - binary_accuracy: 0.9852 - val_loss: -0.9652 - val_dice_coef: 0.9652 - val_binary_accuracy: 0.9828 - lr: 1.2500e-05
# Epoch 49/50
# 36/36 [==============================] - ETA: 0s - loss: -0.9707 - dice_coef: 0.9706 - binary_accuracy: 0.9853
# Epoch 49: val_loss did not improve from -0.96550
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 36/36 [==============================] - 12s 335ms/step - loss: -0.9707 - dice_coef: 0.9706 - binary_accuracy: 0.9853 - val_loss: -0.9653 - val_dice_coef: 0.9653 - val_binary_accuracy: 0.9829 - lr: 1.2500e-05

# %% [markdown]
# ## Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %% [markdown]
# ## Test the model

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Pridiction")
# Out:
# 3/3 [==============================] - 6s 938ms/step

# %%
import matplotlib.pyplot as plt

# %%
img.shape
# Out:
# (256, 256)

# %%
plt.imshow(img)

# %%
im11= np.reshape(img, (1,256,256,1))

# %%
im11
# Out:
# array([[[[234],
#          [219],
#          [208],
#          ...,
#          [152],
#          [145],
#          [131]],
#
#         [[228],
#          [214],
#          [202],
#          ...,
#          [152],
#          [141],
#          [134]],
#
#         [[227],
#          [215],
#          [204],
#          ...,
#          [154],
#          [147],
#          [138]],
#
#         ...,
#
#         [[226],
#          [219],
#          [218],
#          ...,
#          [ 86],
#          [125],
#          [156]],
#
#         [[235],
#          [229],
#          [228],
#          ...,
#          [102],
#          [140],
#          [168]],
#
#         [[240],
#          [235],
#          [234],
#          ...,
#          [139],
#          [163],
#          [189]]]], dtype=uint8)

# %%
pred = model.predict(im11)
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
pred = np.squeeze(pred)
plt.imshow(pred,cmap='gray')
plt.show()

# %%
print("Original Chest X-Ray")
plt.imshow(img)
# Out:
# Original Chest X-Ray

# %%
print("UNet Segmentation")
plt.imshow(pred)
# Out:
# UNet Segmentation
